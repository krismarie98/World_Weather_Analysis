# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates =list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city #.replace("","+")
    #print(city_url)
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrpt=city_weather["weather"][0]["description"]    
            
         # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                           "Lat": city_lat,
                           "Lng": city_lng,
                           "Country": city_country,
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Current Description":city_descrpt})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 1 | san ramon de la nueva oran
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | balkanabat
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | tangwani
# Processing Record 10 of Set 1 | inhambane
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | verkhnevilyuysk
# Processing Record 14 of Set 1 | pisco
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | banda aceh
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | ecoporanga
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | mantua
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | isangel
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | tabulbah
# City not found. Skipping...
# Processing Record 33 of Set 1 | labuhan
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | krasnoselkup
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | roma
# Processing Record 39 of Set 1 | wageningen
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | miri
# Processing Record 43 of Set 1 | tongzi
# Processing Record 44 of Set 1 | teupasenti
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | turukhansk
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | kabin buri
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | mehamn
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | graulhet
# Processing Record 10 of Set 2 | christchurch
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | lhokseumawe
# Processing Record 13 of Set 2 | paamiut
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | robertsport
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | broome
# Processing Record 21 of Set 2 | bosaso
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | caravelas
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | la orilla
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | port augusta
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 2 | cimarron hills
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | sirjan
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 2 | kiama
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | madimba
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | jardim
# Processing Record 44 of Set 2 | korla
# Processing Record 45 of Set 2 | mazagao
# Processing Record 46 of Set 2 | pelym
# Processing Record 47 of Set 2 | razole
# Processing Record 48 of Set 2 | clyde river
# Processing Record 49 of Set 2 | qui nhon
# Processing Record 50 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 3 | atbasar
# Processing Record 2 of Set 3 | los llanos de aridane
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | hamirpur
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | quatre cocos
# Processing Record 8 of Set 3 | flinders
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | banepa
# Processing Record 11 of Set 3 | sinnamary
# Processing Record 12 of Set 3 | khash
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | barraute
# Processing Record 15 of Set 3 | montes altos
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | nishihara
# Processing Record 18 of Set 3 | constitucion
# Processing Record 19 of Set 3 | dogondoutchi
# Processing Record 20 of Set 3 | saint-leu
# Processing Record 21 of Set 3 | hay river
# Processing Record 22 of Set 3 | chicama
# Processing Record 23 of Set 3 | benghazi
# Processing Record 24 of Set 3 | itoman
# Processing Record 25 of Set 3 | busselton
# Processing Record 26 of Set 3 | tazovskiy
# Processing Record 27 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 3 | dungarpur
# Processing Record 29 of Set 3 | cabo san lucas
# Processing Record 30 of Set 3 | tanete
# Processing Record 31 of Set 3 | grindavik
# Processing Record 32 of Set 3 | grand-lahou
# Processing Record 33 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 3 | coahuayana
# Processing Record 35 of Set 3 | tessalit
# Processing Record 36 of Set 3 | cabiraoan
# Processing Record 37 of Set 3 | dzilam gonzalez
# Processing Record 38 of Set 3 | mazatlan
# Processing Record 39 of Set 3 | kapaa
# Processing Record 40 of Set 3 | kamenka
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | dalby
# Processing Record 43 of Set 3 | vao
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | isiro
# Processing Record 46 of Set 3 | katsuura
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | inirida
# Processing Record 49 of Set 3 | broken hill
# Processing Record 50 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 4 | iznoski
# Processing Record 4 of Set 4 | ekimchan
# Processing Record 5 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 4 | kathu
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | boa vista
# Processing Record 9 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 4 | karratha
# Processing Record 11 of Set 4 | diamantino
# Processing Record 12 of Set 4 | klyavlino
# Processing Record 13 of Set 4 | bairiki
# Processing Record 14 of Set 4 | sampang
# Processing Record 15 of Set 4 | cornwall
# Processing Record 16 of Set 4 | baykit
# Processing Record 17 of Set 4 | surt
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | olafsvik
# Processing Record 20 of Set 4 | bandarbeyla
# Processing Record 21 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | kalga
# Processing Record 24 of Set 4 | tuy hoa
# Processing Record 25 of Set 4 | rantepao
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | aranda de duero
# Processing Record 28 of Set 4 | ziro
# Processing Record 29 of Set 4 | masvingo
# Processing Record 30 of Set 4 | tigil
# Processing Record 31 of Set 4 | hvolsvollur
# Processing Record 32 of Set 4 | namtsy
# Processing Record 33 of Set 4 | paita
# Processing Record 34 of Set 4 | belmonte
# Processing Record 35 of Set 4 | sindor
# Processing Record 36 of Set 4 | beloha
# Processing Record 37 of Set 4 | victoria
# Processing Record 38 of Set 4 | kloulklubed
# Processing Record 39 of Set 4 | chornukhy
# Processing Record 40 of Set 4 | prince rupert
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | puerto escondido
# Processing Record 43 of Set 4 | singosari
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | malakal
# Processing Record 47 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 4 | brokopondo
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | bubaque
# Processing Record 1 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 5 | windhoek
# Processing Record 3 of Set 5 | iqaluit
# Processing Record 4 of Set 5 | ukiah
# Processing Record 5 of Set 5 | karaman
# Processing Record 6 of Set 5 | umm kaddadah
# Processing Record 7 of Set 5 | chengde
# Processing Record 8 of Set 5 | tatsinskaya
# City not found. Skipping...
# Processing Record 9 of Set 5 | la libertad
# Processing Record 10 of Set 5 | coroata
# Processing Record 11 of Set 5 | anajatuba
# Processing Record 12 of Set 5 | bilibino
# Processing Record 13 of Set 5 | kimbe
# Processing Record 14 of Set 5 | jasper
# Processing Record 15 of Set 5 | sabang
# Processing Record 16 of Set 5 | husavik
# Processing Record 17 of Set 5 | port macquarie
# Processing Record 18 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 5 | tengzhou
# Processing Record 20 of Set 5 | abu zabad
# Processing Record 21 of Set 5 | sawtell
# Processing Record 22 of Set 5 | yantzaza
# Processing Record 23 of Set 5 | houma
# Processing Record 24 of Set 5 | soubre
# Processing Record 25 of Set 5 | sendhwa
# Processing Record 26 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | golfito
# Processing Record 29 of Set 5 | cherskiy
# Processing Record 30 of Set 5 | vyartsilya
# Processing Record 31 of Set 5 | puerto leguizamo
# Processing Record 32 of Set 5 | camacha
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | aswan
# Processing Record 35 of Set 5 | chegdomyn
# Processing Record 36 of Set 5 | hobart
# Processing Record 37 of Set 5 | tiarei
# Processing Record 38 of Set 5 | severnyy
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | mabaruma
# Processing Record 41 of Set 5 | touros
# Processing Record 42 of Set 5 | tall kayf
# Processing Record 43 of Set 5 | dombarovskiy
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | dhidhdhoo
# Processing Record 46 of Set 5 | horsham
# Processing Record 47 of Set 5 | moron
# Processing Record 48 of Set 5 | konotop
# Processing Record 49 of Set 5 | verkhnetulomskiy
# Processing Record 50 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 6 | olinala
# Processing Record 2 of Set 6 | leningradskiy
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | wajid
# Processing Record 5 of Set 6 | plettenberg bay
# Processing Record 6 of Set 6 | luyang
# Processing Record 7 of Set 6 | alofi
# Processing Record 8 of Set 6 | saint george
# Processing Record 9 of Set 6 | mosina
# Processing Record 10 of Set 6 | vung tau
# Processing Record 11 of Set 6 | lagunas
# Processing Record 12 of Set 6 | kohima
# Processing Record 13 of Set 6 | sur
# Processing Record 14 of Set 6 | bulgan
# Processing Record 15 of Set 6 | olpad
# Processing Record 16 of Set 6 | yumen
# Processing Record 17 of Set 6 | nyamuswa
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | hualmay
# Processing Record 20 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 6 | borborema
# Processing Record 22 of Set 6 | oranjestad
# Processing Record 23 of Set 6 | maceio
# Processing Record 24 of Set 6 | kaitangata
# Processing Record 25 of Set 6 | poum
# Processing Record 26 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 27 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 6 | beyneu
# Processing Record 29 of Set 6 | hede
# Processing Record 30 of Set 6 | upernavik
# Processing Record 31 of Set 6 | fortuna
# Processing Record 32 of Set 6 | bahia blanca
# Processing Record 33 of Set 6 | cutro
# Processing Record 34 of Set 6 | lohardaga
# Processing Record 35 of Set 6 | saint anthony
# Processing Record 36 of Set 6 | coxim
# Processing Record 37 of Set 6 | mogadishu
# Processing Record 38 of Set 6 | lorengau
# Processing Record 39 of Set 6 | salinopolis
# Processing Record 40 of Set 6 | kang
# Processing Record 41 of Set 6 | santa maria
# Processing Record 42 of Set 6 | college
# Processing Record 43 of Set 6 | asau
# Processing Record 44 of Set 6 | nara
# Processing Record 45 of Set 6 | tateyama
# Processing Record 46 of Set 6 | marawi
# Processing Record 47 of Set 6 | salta
# Processing Record 48 of Set 6 | kiunga
# Processing Record 49 of Set 6 | amancio
# City not found. Skipping...
# Processing Record 50 of Set 6 | lodja
# Processing Record 1 of Set 7 | tual
# Processing Record 2 of Set 7 | flin flon
# Processing Record 3 of Set 7 | haines junction
# Processing Record 4 of Set 7 | santa luzia
# Processing Record 5 of Set 7 | nikolskoye
# Processing Record 6 of Set 7 | mus
# Processing Record 7 of Set 7 | ancud
# Processing Record 8 of Set 7 | champerico
# Processing Record 9 of Set 7 | maridi
# Processing Record 10 of Set 7 | kodiak
# Processing Record 11 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 12 of Set 7 | najran
# Processing Record 13 of Set 7 | wembley
# Processing Record 14 of Set 7 | vincennes
# Processing Record 15 of Set 7 | sonder bjert
# Processing Record 16 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 7 | brunsbuttel
# Processing Record 18 of Set 7 | sillanwali
# Processing Record 19 of Set 7 | do rud
# City not found. Skipping...
# Processing Record 20 of Set 7 | longyearbyen
# Processing Record 21 of Set 7 | ilam
# Processing Record 22 of Set 7 | waingapu
# Processing Record 23 of Set 7 | solnechnyy
# Processing Record 24 of Set 7 | lae
# Processing Record 25 of Set 7 | sao joao da barra
# Processing Record 26 of Set 7 | rawson
# Processing Record 27 of Set 7 | guerrero negro
# Processing Record 28 of Set 7 | voh
# Processing Record 29 of Set 7 | dandong
# Processing Record 30 of Set 7 | vardo
# Processing Record 31 of Set 7 | aitape
# Processing Record 32 of Set 7 | grand island
# Processing Record 33 of Set 7 | osmena
# Processing Record 34 of Set 7 | kruisfontein
# Processing Record 35 of Set 7 | samarai
# Processing Record 36 of Set 7 | zhangjiakou
# Processing Record 37 of Set 7 | somerset east
# Processing Record 38 of Set 7 | san andres
# Processing Record 39 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 7 | fethiye
# Processing Record 41 of Set 7 | savasleyka
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | warman
# Processing Record 44 of Set 7 | elk grove
# Processing Record 45 of Set 7 | midland
# Processing Record 46 of Set 7 | shimoda
# Processing Record 47 of Set 7 | ipixuna
# Processing Record 48 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 7 | ust-kut
# Processing Record 50 of Set 7 | wasilla
# Processing Record 1 of Set 8 | mlimba
# Processing Record 2 of Set 8 | bull savanna
# Processing Record 3 of Set 8 | bambous virieux
# Processing Record 4 of Set 8 | homa bay
# Processing Record 5 of Set 8 | luanshya
# Processing Record 6 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | raudeberg
# Processing Record 9 of Set 8 | jepelacio
# Processing Record 10 of Set 8 | moen
# Processing Record 11 of Set 8 | otane
# Processing Record 12 of Set 8 | sakakah
# Processing Record 13 of Set 8 | terrace bay
# Processing Record 14 of Set 8 | magsaysay
# Processing Record 15 of Set 8 | imbituba
# Processing Record 16 of Set 8 | te anau
# Processing Record 17 of Set 8 | soyo
# Processing Record 18 of Set 8 | namatanai
# Processing Record 19 of Set 8 | emerald
# Processing Record 20 of Set 8 | nantucket
# Processing Record 21 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 8 | linxia
# Processing Record 23 of Set 8 | arman
# Processing Record 24 of Set 8 | clarence town
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | santa vitoria do palmar
# Processing Record 27 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 8 | acarau
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | san rafael
# Processing Record 31 of Set 8 | tabatinga
# Processing Record 32 of Set 8 | portland
# Processing Record 33 of Set 8 | dongsheng
# Processing Record 34 of Set 8 | jalu
# Processing Record 35 of Set 8 | bijapur
# Processing Record 36 of Set 8 | marathon
# Processing Record 37 of Set 8 | walvis bay
# Processing Record 38 of Set 8 | chateaubelair
# Processing Record 39 of Set 8 | kabare
# Processing Record 40 of Set 8 | ngunguru
# Processing Record 41 of Set 8 | vila franca do campo
# Processing Record 42 of Set 8 | yerbogachen
# Processing Record 43 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 8 | quelimane
# Processing Record 45 of Set 8 | boundiali
# Processing Record 46 of Set 8 | dalvik
# Processing Record 47 of Set 8 | jablah
# Processing Record 48 of Set 8 | srednekolymsk
# Processing Record 49 of Set 8 | mana
# Processing Record 50 of Set 8 | san juan
# Processing Record 1 of Set 9 | quesnel
# Processing Record 2 of Set 9 | yuzhnyy
# Processing Record 3 of Set 9 | dobryatino
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | saint-joseph
# Processing Record 6 of Set 9 | paka
# Processing Record 7 of Set 9 | buala
# Processing Record 8 of Set 9 | yambio
# Processing Record 9 of Set 9 | barra do garcas
# Processing Record 10 of Set 9 | tura
# Processing Record 11 of Set 9 | bodden town
# Processing Record 12 of Set 9 | kawalu
# Processing Record 13 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 9 | grand gaube
# Processing Record 15 of Set 9 | changtu
# Processing Record 16 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 9 | kaputa
# Processing Record 18 of Set 9 | monrovia
# Processing Record 19 of Set 9 | rascani
# City not found. Skipping...
# Processing Record 20 of Set 9 | roberval
# Processing Record 21 of Set 9 | malibu
# Processing Record 22 of Set 9 | andover
# Processing Record 23 of Set 9 | marystown
# Processing Record 24 of Set 9 | sahuaripa
# Processing Record 25 of Set 9 | yar-sale
# Processing Record 26 of Set 9 | kahului
# Processing Record 27 of Set 9 | gardan diwal
# City not found. Skipping...
# Processing Record 28 of Set 9 | havelock
# Processing Record 29 of Set 9 | kitaibaraki
# Processing Record 30 of Set 9 | seidu
# Processing Record 31 of Set 9 | el carmen
# Processing Record 32 of Set 9 | kanniyakumari
# Processing Record 33 of Set 9 | pilu
# Processing Record 34 of Set 9 | saint-augustin
# Processing Record 35 of Set 9 | gat
# Processing Record 36 of Set 9 | pangody
# Processing Record 37 of Set 9 | chishtian mandi
# Processing Record 38 of Set 9 | ahmadpur
# Processing Record 39 of Set 9 | bathsheba
# Processing Record 40 of Set 9 | russell
# Processing Record 41 of Set 9 | mixtepec
# City not found. Skipping...
# Processing Record 42 of Set 9 | yurimaguas
# Processing Record 43 of Set 9 | phonhong
# Processing Record 44 of Set 9 | general pico
# Processing Record 45 of Set 9 | straumen
# Processing Record 46 of Set 9 | boatlaname
# City not found. Skipping...
# Processing Record 47 of Set 9 | sola
# Processing Record 48 of Set 9 | mandalgovi
# Processing Record 49 of Set 9 | salalah
# Processing Record 50 of Set 9 | pareora
# Processing Record 1 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 10 | newala
# Processing Record 3 of Set 10 | fukue
# Processing Record 4 of Set 10 | xining
# Processing Record 5 of Set 10 | riyadh
# Processing Record 6 of Set 10 | witrivier
# City not found. Skipping...
# Processing Record 7 of Set 10 | natal
# Processing Record 8 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 9 of Set 10 | ranfurly
# Processing Record 10 of Set 10 | ulaanbaatar
# Processing Record 11 of Set 10 | shatalovo
# Processing Record 12 of Set 10 | minab
# Processing Record 13 of Set 10 | camacupa
# Processing Record 14 of Set 10 | seymchan
# Processing Record 15 of Set 10 | dunedin
# Processing Record 16 of Set 10 | waw
# Processing Record 17 of Set 10 | takefu
# Processing Record 18 of Set 10 | praia da vitoria
# Processing Record 19 of Set 10 | nuuk
# Processing Record 20 of Set 10 | silikatnyy
# Processing Record 21 of Set 10 | port hardy
# Processing Record 22 of Set 10 | fereydunshahr
# Processing Record 23 of Set 10 | avera
# Processing Record 24 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 10 | gamboma
# Processing Record 26 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 10 | hirara
# Processing Record 28 of Set 10 | burias
# Processing Record 29 of Set 10 | ardrishaig
# Processing Record 30 of Set 10 | hazorasp
# Processing Record 31 of Set 10 | ahipara
# Processing Record 32 of Set 10 | san isidro
# Processing Record 33 of Set 10 | los chiles
# Processing Record 34 of Set 10 | tomatlan
# Processing Record 35 of Set 10 | sobolevo
# Processing Record 36 of Set 10 | conceicao do araguaia
# Processing Record 37 of Set 10 | teya
# Processing Record 38 of Set 10 | sarangani
# Processing Record 39 of Set 10 | eureka
# Processing Record 40 of Set 10 | chulumani
# Processing Record 41 of Set 10 | parakou
# Processing Record 42 of Set 10 | kijang
# Processing Record 43 of Set 10 | lazaro cardenas
# Processing Record 44 of Set 10 | san cristobal
# Processing Record 45 of Set 10 | gimli
# Processing Record 46 of Set 10 | coihaique
# Processing Record 47 of Set 10 | sitka
# Processing Record 48 of Set 10 | jijiga
# Processing Record 49 of Set 10 | noumea
# Processing Record 50 of Set 10 | lavrentiya
# Processing Record 1 of Set 11 | bestobe
# Processing Record 2 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 11 | dakar
# Processing Record 4 of Set 11 | monte azul
# Processing Record 5 of Set 11 | kyaikto
# Processing Record 6 of Set 11 | egvekinot
# Processing Record 7 of Set 11 | henties bay
# Processing Record 8 of Set 11 | cotonou
# Processing Record 9 of Set 11 | xiaoweizhai
# Processing Record 10 of Set 11 | cockburn town
# Processing Record 11 of Set 11 | pathein
# Processing Record 12 of Set 11 | mount isa
# Processing Record 13 of Set 11 | aksu
# Processing Record 14 of Set 11 | sept-iles
# Processing Record 15 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 16 of Set 11 | gaziantep
# Processing Record 17 of Set 11 | abu dhabi
# Processing Record 18 of Set 11 | bentiu
# Processing Record 19 of Set 11 | padang
# Processing Record 20 of Set 11 | nelson bay
# Processing Record 21 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 22 of Set 11 | karavukovo
# Processing Record 23 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 11 | meadow lake
# Processing Record 25 of Set 11 | dudinka
# Processing Record 26 of Set 11 | viedma
# Processing Record 27 of Set 11 | kisangani
# Processing Record 28 of Set 11 | burica
# City not found. Skipping...
# Processing Record 29 of Set 11 | sawakin
# Processing Record 30 of Set 11 | magdalena
# Processing Record 31 of Set 11 | ongandjera
# Processing Record 32 of Set 11 | berlevag
# Processing Record 33 of Set 11 | namibe
# Processing Record 34 of Set 11 | poronaysk
# Processing Record 35 of Set 11 | saint-die
# City not found. Skipping...
# Processing Record 36 of Set 11 | sovik
# Processing Record 37 of Set 11 | conakry
# Processing Record 38 of Set 11 | rosetta
# Processing Record 39 of Set 11 | saltpond
# Processing Record 40 of Set 11 | morondava
# Processing Record 41 of Set 11 | zabol
# Processing Record 42 of Set 11 | pedasi
# Processing Record 43 of Set 11 | jumla
# Processing Record 44 of Set 11 | slave lake
# Processing Record 45 of Set 11 | bandar-e lengeh
# Processing Record 46 of Set 11 | dymer
# Processing Record 47 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 48 of Set 11 | maxixe
# Processing Record 49 of Set 11 | asfi
# Processing Record 50 of Set 11 | sao filipe
# Processing Record 1 of Set 12 | mangrol
# Processing Record 2 of Set 12 | aketi
# Processing Record 3 of Set 12 | catuday
# Processing Record 4 of Set 12 | saravan
# Processing Record 5 of Set 12 | letlhakane
# Processing Record 6 of Set 12 | meulaboh
# Processing Record 7 of Set 12 | obo
# Processing Record 8 of Set 12 | pocatello
# Processing Record 9 of Set 12 | artesia
# Processing Record 10 of Set 12 | louisville
# Processing Record 11 of Set 12 | puerto cabezas
# Processing Record 12 of Set 12 | herzberg
# Processing Record 13 of Set 12 | chuy
# Processing Record 14 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 12 | danbury
# Processing Record 16 of Set 12 | alekseyevskaya
# Processing Record 17 of Set 12 | lincoln
# Processing Record 18 of Set 12 | umm lajj
# Processing Record 19 of Set 12 | bow island
# Processing Record 20 of Set 12 | port hawkesbury
# Processing Record 21 of Set 12 | mayya
# Processing Record 22 of Set 12 | lompoc
# Processing Record 23 of Set 12 | wanganui
# Processing Record 24 of Set 12 | bourail
# Processing Record 25 of Set 12 | san policarpo
# Processing Record 26 of Set 12 | khandbari
# Processing Record 27 of Set 12 | protvino
# Processing Record 28 of Set 12 | bryukhovetskaya
# Processing Record 29 of Set 12 | zwedru
# Processing Record 30 of Set 12 | komsomolskiy
# Processing Record 31 of Set 12 | deputatskiy
# Processing Record 32 of Set 12 | boca do acre
# Processing Record 33 of Set 12 | abomey
# Processing Record 34 of Set 12 | la ronge
# Processing Record 35 of Set 12 | palmer
# Processing Record 36 of Set 12 | mayo
# Processing Record 37 of Set 12 | iguape
# Processing Record 38 of Set 12 | lere
# Processing Record 39 of Set 12 | adrar
# Processing Record 40 of Set 12 | wolfhagen
# Processing Record 41 of Set 12 | vanavara
# Processing Record 42 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 12 | marienburg
# Processing Record 44 of Set 12 | heihe
# Processing Record 45 of Set 12 | caldwell
# Processing Record 46 of Set 12 | tuatapere
# Processing Record 47 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 48 of Set 12 | steamboat springs
# Processing Record 49 of Set 12 | narsaq
# Processing Record 50 of Set 12 | edgemoor
# Processing Record 1 of Set 13 | salekhard
# Processing Record 2 of Set 13 | ipilan
# Processing Record 3 of Set 13 | karaton
# Processing Record 4 of Set 13 | svetlogorsk
# Processing Record 5 of Set 13 | nouadhibou
# Processing Record 6 of Set 13 | jatiroto
# Processing Record 7 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 13 | balikpapan
# Processing Record 9 of Set 13 | fosforitnyy
# Processing Record 10 of Set 13 | nome
# Processing Record 11 of Set 13 | osoyoos
# Processing Record 12 of Set 13 | port blair
# Processing Record 13 of Set 13 | cheyenne
# Processing Record 14 of Set 13 | sangar
# Processing Record 15 of Set 13 | vostok
# Processing Record 16 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 17 of Set 13 | sandwick
# Processing Record 18 of Set 13 | aykhal
# Processing Record 19 of Set 13 | bambanglipuro
# Processing Record 20 of Set 13 | juegang
# Processing Record 21 of Set 13 | ha tinh
# Processing Record 22 of Set 13 | ravar
# Processing Record 23 of Set 13 | darhan
# Processing Record 24 of Set 13 | urambo
# Processing Record 25 of Set 13 | coquimbo
# Processing Record 26 of Set 13 | bantigue
# Processing Record 27 of Set 13 | norsup
# Processing Record 28 of Set 13 | mitzic
# Processing Record 29 of Set 13 | ixtapa
# Processing Record 30 of Set 13 | tocopilla
# Processing Record 31 of Set 13 | mopipi
# Processing Record 32 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 33 of Set 13 | sevnica
# Processing Record 34 of Set 13 | sohna
# Processing Record 35 of Set 13 | gizo
# Processing Record 36 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 13 | aqtobe
# Processing Record 38 of Set 13 | trenggalek
# Processing Record 39 of Set 13 | hami
# Processing Record 40 of Set 13 | syracuse
# Processing Record 41 of Set 13 | nabire
# Processing Record 42 of Set 13 | mapastepec
# Processing Record 43 of Set 13 | manyana
# Processing Record 44 of Set 13 | rabo de peixe
# Processing Record 45 of Set 13 | paidha
# Processing Record 46 of Set 13 | marsh harbour
# Processing Record 47 of Set 13 | atasu
# Processing Record 48 of Set 13 | benguela
# Processing Record 49 of Set 13 | ambon
# Processing Record 50 of Set 13 | chickasha
# Processing Record 1 of Set 14 | letterkenny
# Processing Record 2 of Set 14 | montgomery
# Processing Record 3 of Set 14 | acajutla
# Processing Record 4 of Set 14 | merke
# Processing Record 5 of Set 14 | mount gambier
# Processing Record 6 of Set 14 | le vauclin
# Processing Record 7 of Set 14 | hohhot
# Processing Record 8 of Set 14 | alice springs
# Processing Record 9 of Set 14 | goure
# Processing Record 10 of Set 14 | bograd
# Processing Record 11 of Set 14 | roebourne
# Processing Record 12 of Set 14 | concepcion del oro
# Processing Record 13 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 14 | ocampo
# Processing Record 15 of Set 14 | ostrovnoy
# Processing Record 16 of Set 14 | ballina
# Processing Record 17 of Set 14 | vanimo
# Processing Record 18 of Set 14 | cherkasskoye
# Processing Record 19 of Set 14 | jaguarari
# Processing Record 20 of Set 14 | rio gallegos
# Processing Record 21 of Set 14 | cap malheureux
# Processing Record 22 of Set 14 | glyadyanskoye
# Processing Record 23 of Set 14 | ishigaki
# Processing Record 24 of Set 14 | burnie
# Processing Record 25 of Set 14 | awbari
# Processing Record 26 of Set 14 | kuusamo
# Processing Record 27 of Set 14 | wahpeton
# Processing Record 28 of Set 14 | sungai kolok
# City not found. Skipping...
# Processing Record 29 of Set 14 | never
# Processing Record 30 of Set 14 | glace bay
# Processing Record 31 of Set 14 | pitimbu
# Processing Record 32 of Set 14 | bardiyah
# Processing Record 33 of Set 14 | mancio lima
# Processing Record 34 of Set 14 | nalut
# Processing Record 35 of Set 14 | alto araguaia
# Processing Record 36 of Set 14 | kieta
# Processing Record 37 of Set 14 | ust-koksa
# Processing Record 38 of Set 14 | milton
# Processing Record 39 of Set 14 | buraydah
# Processing Record 40 of Set 14 | kazuno
# Processing Record 41 of Set 14 | lingao
# Processing Record 42 of Set 14 | gaillac
# Processing Record 43 of Set 14 | sorland
# Processing Record 44 of Set 14 | lubbock
# Processing Record 45 of Set 14 | sibolga
# Processing Record 46 of Set 14 | skibbereen
# Processing Record 47 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 14 | muros
# Processing Record 49 of Set 14 | luhyny
# Processing Record 50 of Set 14 | pereslavl-zalesskiy
# Processing Record 1 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 15 | kuznechnoye
# Processing Record 3 of Set 15 | akureyri
# Processing Record 4 of Set 15 | ofunato
# Processing Record 5 of Set 15 | puerto narino
# Processing Record 6 of Set 15 | sahbuz
# Processing Record 7 of Set 15 | zachepylivka
# Processing Record 8 of Set 15 | thai binh
# Processing Record 9 of Set 15 | mubi
# Processing Record 10 of Set 15 | matara
# Processing Record 11 of Set 15 | curup
# Processing Record 12 of Set 15 | amga
# Processing Record 13 of Set 15 | rauma
# Processing Record 14 of Set 15 | hovd
# Processing Record 15 of Set 15 | high level
# Processing Record 16 of Set 15 | forio
# Processing Record 17 of Set 15 | puerto ayacucho
# Processing Record 18 of Set 15 | blackfoot
# Processing Record 19 of Set 15 | innisfail
# Processing Record 20 of Set 15 | calderitas
# Processing Record 21 of Set 15 | gigmoto
# Processing Record 22 of Set 15 | thinadhoo
# Processing Record 23 of Set 15 | namie
# Processing Record 24 of Set 15 | skjervoy
# Processing Record 25 of Set 15 | chany
# Processing Record 26 of Set 15 | knysna
# Processing Record 27 of Set 15 | eydhafushi
# Processing Record 28 of Set 15 | yulara
# Processing Record 29 of Set 15 | shepsi
# Processing Record 30 of Set 15 | aklavik
# Processing Record 31 of Set 15 | qasigiannguit
# Processing Record 32 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 33 of Set 15 | lasa
# Processing Record 34 of Set 15 | rochegda
# Processing Record 35 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 15 | kollam
# Processing Record 37 of Set 15 | vestmannaeyjar
# Processing Record 38 of Set 15 | parjol
# Processing Record 39 of Set 15 | xuddur
# Processing Record 40 of Set 15 | biskamzha
# Processing Record 41 of Set 15 | kidal
# Processing Record 42 of Set 15 | jiaonan
# Processing Record 43 of Set 15 | kamiiso
# Processing Record 44 of Set 15 | teahupoo
# Processing Record 45 of Set 15 | rocha
# Processing Record 46 of Set 15 | batagay
# Processing Record 47 of Set 15 | jucurutu
# Processing Record 48 of Set 15 | atar
# Processing Record 49 of Set 15 | arequipa
# Processing Record 50 of Set 15 | ailigandi
# Processing Record 1 of Set 16 | ninomiya
# Processing Record 2 of Set 16 | kroya
# Processing Record 3 of Set 16 | yarada
# Processing Record 4 of Set 16 | tsiroanomandidy
# Processing Record 5 of Set 16 | gwadar
# Processing Record 6 of Set 16 | khuzdar
# Processing Record 7 of Set 16 | rodrigues alves
# Processing Record 8 of Set 16 | misratah
# Processing Record 9 of Set 16 | lahij
# Processing Record 10 of Set 16 | kununurra
# Processing Record 11 of Set 16 | faya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                          City      Lat       Lng Country  Max Temp  Humidity  \
# 0                       Airai  -8.9266  125.4092      TL     63.12        93
# 1  San Ramon De La Nueva Oran -23.1322  -64.3260      AR     72.43        67
# 2                   Carnarvon -24.8667  113.6333      AU     65.91        68
# 3                   Hithadhoo  -0.6000   73.0833      MV     82.00        70
# 4                  Balkanabat  39.5108   54.3671      TM     73.74        40
# 5                     Ushuaia -54.8000  -68.3000      AR     55.06        30
# 6                    Tangwani  28.2787   68.9972      PK     81.21        19
# 7                   Inhambane -23.8650   35.3833      MZ     82.38        57
# 8              Saint-Philippe -21.3585   55.7679      RE     74.79        83
# 9              Ribeira Grande  38.5167  -28.7000      PT     63.00        59
#
#    Cloudiness  Wind Speed Current Description
# 0         100        0.25     overcast clouds
# 1         100        4.25     overcast clouds
# 2           0       26.33           clear sky
# 3          97        9.98     overcast clouds
# 4          26        4.50    scattered clouds
# 5           0        1.14           clear sky
# 6           0        5.06           clear sky
# 7          40       11.50    scattered clouds
# 8          54        9.98       broken clouds
# 9          20       27.63          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Country', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order

city_data_df=city_data_df.reindex(columns=new_order)
# Display sample data

city_data_df.head()
# Out:
#                          City Country      Lat       Lng  Max Temp  Humidity  \
# 0                       Airai      TL  -8.9266  125.4092     63.12        93
# 1  San Ramon De La Nueva Oran      AR -23.1322  -64.3260     72.43        67
# 2                   Carnarvon      AU -24.8667  113.6333     65.91        68
# 3                   Hithadhoo      MV  -0.6000   73.0833     82.00        70
# 4                  Balkanabat      TM  39.5108   54.3671     73.74        40
#
#    Cloudiness  Wind Speed Current Description
# 0         100        0.25     overcast clouds
# 1         100        4.25     overcast clouds
# 2           0       26.33           clear sky
# 3          97        9.98     overcast clouds
# 4          26        4.50    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file="../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file)

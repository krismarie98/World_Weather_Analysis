# %%
# Import the random module
import random

# %%
random.randint(-90,90)
# Out:
# -66

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
random.randrange(-90, 90, step=1)
# Out:
# -69

# %%
random.randrange(-90, 90, step=3)
# Out:
# 60

# %%
random.uniform(-90,90)
# Out:
# 87.9725720498889

# %%
# Import Numpy module
import numpy as np

# %%
np.random.uniform(-90.000,90.000, size =50)
# Out:
# array([-66.70601002,  26.22608977,  70.8586544 ,   9.86315037,
#         72.21227394,  76.05321208, -44.72737086,  56.85899568,
#         32.58639435, -88.54637954, -18.11684792, -65.35309758,
#        -71.36918231, -40.14612283,  33.78265314, -62.40515185,
#         47.07261521, -66.29904493,  88.7164302 ,  73.24354969,
#        -82.31393726,  -9.46367071,  30.56409735, -77.53312122,
#          4.96344113, -52.73969487, -60.9038682 ,  47.41880269,
#        -13.07962014, -84.65024679, -89.49997238, -62.1988797 ,
#         76.42093985, -73.96978076,  79.24882167, -69.03616169,
#         34.05594727,  20.49665634, -70.2340351 ,  63.37412817,
#         25.84691941, -45.69774825,  27.66427622,  29.95773563,
#         44.24863097, -62.78225601,  84.77575618,  38.20050476,
#        -87.25218011, -83.39590415])

# %%
# Import timeit
import timeit

# %%
# %timeit np.random.uniform(-90.000,90.000,size=1500)
# Out:
# 47.6 µs ± 13.2 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 4.53 ms ± 241 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
